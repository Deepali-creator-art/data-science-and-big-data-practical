# %%
# 1 ─── Import the required libraries ──────────────────────────────
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
#2--Load titanic dataset
df = pd.read_csv('/home/kkw/titanic.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={"Sex": "Gender"}, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Typical missing columns:
#
#     age: Many missing values (numeric)
#
#     embarked: A few missing values (categorical)
#
#     Cabin: Many missing values (optional to drop)

# %% [markdown]
# 3. Handle Missing Numeric Values (e.g., Age)
#
# 👉 Use mean, median, or model-based imputation.

# %%
from sklearn.impute import SimpleImputer

# Impute 'age' with median
imputer = SimpleImputer(strategy='median')
df['Age'] = imputer.fit_transform(df[['Age']])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 4. Handle Missing Categorical Values (e.g., Embarked)
#
# 👉 Use most frequent value or constant.

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
nmg = pd.notnull(df["Embarked"])

nmgd= df[nmg]
print(nmgd)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Gender   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
# Impute 'embarked' with most frequent
cat_imputer = SimpleImputer(strategy='most_frequent')
df['Embarked'] = cat_imputer.fit_transform(df[['Embarked']]).ravel()

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.iloc[61]
# Out:
# PassengerId                     62
# Survived                         1
# Pclass                           1
# Name           Icard, Miss. Amelie
# Gender                      female
# Age                           38.0
# SibSp                            0
# Parch                            0
# Ticket                      113572
# Fare                          80.0
# Cabin                          B28
# Embarked                         S
# Name: 61, dtype: object

# %%
df.iloc[829]
# Out:
# PassengerId                                          830
# Survived                                               1
# Pclass                                                 1
# Name           Stone, Mrs. George Nelson (Martha Evelyn)
# Gender                                            female
# Age                                                 62.0
# SibSp                                                  0
# Parch                                                  0
# Ticket                                            113572
# Fare                                                80.0
# Cabin                                                B28
# Embarked                                               S
# Name: 829, dtype: object

# %% [markdown]
# 5. Drop Columns with Too Many Missing Values (Optional)
#
# 👉 For example, Cabin is often >75% missing. You can drop it.

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Gender         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# 6. Verify Missing Data is Handled

# %%
print("\nRemaining missing values:")
print(df.isnull().sum())
# Out:
# Remaining missing values:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Gender         0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Display stastics
# using describe() function

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='object')
# Out:
#                            Name Gender  Ticket Embarked
# count                       891    891     891      891
# unique                      891      2     681        3
# top     Braund, Mr. Owen Harris   male  347082        S
# freq                          1    577       7      646

# %%
num_cols = df.select_dtypes(include=np.number).columns
print(num_cols.tolist())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
from scipy.stats import zscore
#parameter nan_policy = 'omit' and nans are ignored in the calculation

z_scores = df[num_cols].apply(zscore, nan_policy="omit")
print(z_scores)
# Flag anything with |z| ≥ 3
mask_z = (np.abs(z_scores) >= 3)

out_z = (mask_z.sum()
         .reset_index()
         .rename(columns={"index": "column", 0: "n_outliers"}))
print(out_z.sort_values("n_outliers", ascending=False))
# Out:
#      PassengerId  Survived    Pclass       Age     SibSp     Parch      Fare
# 0      -1.730108 -0.789272  0.827377 -0.565736  0.432793 -0.473674 -0.502445
# 1      -1.726220  1.266990 -1.566107  0.663861  0.432793 -0.473674  0.786845
# 2      -1.722332  1.266990  0.827377 -0.258337 -0.474545 -0.473674 -0.488854
# 3      -1.718444  1.266990 -1.566107  0.433312  0.432793 -0.473674  0.420730
# 4      -1.714556 -0.789272  0.827377  0.433312 -0.474545 -0.473674 -0.486337
# ..           ...       ...       ...       ...       ...       ...       ...
# 886     1.714556 -0.789272 -0.369365 -0.181487 -0.474545 -0.473674 -0.386671
# 887     1.718444  1.266990 -1.566107 -0.796286 -0.474545 -0.473674 -0.044381
# 888     1.722332 -0.789272  0.827377 -0.104637  0.432793  2.008933 -0.176263
# 889     1.726220  1.266990 -1.566107 -0.258337 -0.474545 -0.473674 -0.044381
# 890     1.730108 -0.789272  0.827377  0.202762 -0.474545 -0.473674 -0.492378
#
# [891 rows x 7 columns]
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['age_scaled'] = scaler.fit_transform(df[['Age']])

# %% [markdown]
# Label‑encode a binary column (e.g. Sex)

# %%
df['Gender_bin'] = df['Gender'].map({'male': 1, 'female': 0})
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender_bin'] = le.fit_transform(df['Gender'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
import matplotlib.pyplot as plt
data = [20, 21, 22, 20, 67, 19, 18, 21, 20, 21, 20, 18, 19, 20, 21]
df = pd.DataFrame(data, columns=['Age'])

# %%
df['Age'].mean()
# Out:
# 23.133333333333333

# %%
df['Age'].std()
# Out:
# 12.188206633971255

# %%
df['Z-score'] = zscore(df['Age'])
print(df)
# Out:
#     Age   Z-score
# 0    20 -0.266102
# 1    21 -0.181176
# 2    22 -0.096250
# 3    20 -0.266102
# 4    67  3.725430
# 5    19 -0.351028
# 6    18 -0.435955
# 7    21 -0.181176
# 8    20 -0.266102
# 9    21 -0.181176
# 10   20 -0.266102
# 11   18 -0.435955
# 12   19 -0.351028
# 13   20 -0.266102
# 14   21 -0.181176

# %%
(67-23)/12.88
# Out:
# 3.4161490683229814

# %%
outliers = df[df['Z-score'].abs() > 3]
print(outliers)
# Out:
#    Age  Z-score
# 4   67  3.72543
